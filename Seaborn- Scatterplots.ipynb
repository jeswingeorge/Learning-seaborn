# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
sns.set(rc = {'figure.figsize':(10, 8)}, font_scale=1.5)

# %% [markdown]
# ### Ref : [Visualizing statistical relationships](https://seaborn.pydata.org/tutorial/relational.html#relational-tutorial)
#
# __[seaborn.load_dataset()](https://seaborn.pydata.org/generated/seaborn.load_dataset.html)__ : Load a dataset from the online repository (requires internet).
#
#
# [Tips Dataset](https://www.kaggle.com/ranjeetjain3/seaborn-tips-dataset)

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## [Scatterplot](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)
#
#
# Plotting  a simple scatter plot between two variables: total_bill vs tips.
#
# - __hue__: Grouping variable that will produce points with different colors. Can be either categorical or numeric.
# - __size__: Grouping variable that will produce points with different sizes. Can be either categorical or numeric.

# %%
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip');

# %% [markdown]
# 2. Group by another variable and show the groups with different colors:

# %%
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip', hue = 'time' );

# %% [markdown]
# Show the grouping variable by varying both color and marker:

# %%
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip', hue = 'time', style = 'time');

# %% [markdown]
# Vary colors and markers to show two different grouping variables:

# %%
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip', 
                hue = 'day', style = 'time');

# %% [markdown]
# Show a quantitative variable by varying the size of the points:

# %%
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip', 
                 size = 'size');

# %% [markdown]
# Also show the quantitative variable by also using continuous colors:

# %%
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip', hue = 'size',
                 size = 'size');

# %% [markdown]
# [sequential-color-palettes](https://seaborn.pydata.org/tutorial/color_palettes.html#sequential-color-palettes)
#
# The cubehelix color palette system makes sequential palettes with a linear increase or decrease in brightness and some variation in hue. This means that the information in your colormap will be preserved when converted to black and white (for printing) or when viewed by a colorblind individual.
#
# Matplotlib has the default cubehelix version built into it:

# %%
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip', hue = 'size',
                 size = 'size',  palette=cmap);

# %% [markdown]
# Change the minimum and maximum point size and show all sizes in legend:

# %%
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
sns.scatterplot(data = tips, x = 'total_bill', y = 'tip', hue = 'size',  sizes=(20, 200),
                 size = 'size',  palette=cmap, legend = "full");

# %% [markdown]
# Pass a wide-form dataset and plot against its index:

# %%
index = pd.date_range("1 1 2000", periods=100,
                      freq="m", name="date")
data = np.random.randn(100, 4).cumsum(axis=0)

# %%
wide_df = pd.DataFrame(data, index, ["a", "b", "c", "d"])
wide_df.head()
# Out:
#                    a         b         c         d
# date
# 2000-01-31  0.436621 -0.194796 -0.302152  0.360681
# 2000-02-29  0.760123 -1.656759 -0.752274  0.909732
# 2000-03-31  1.248784 -1.735289 -1.019419  1.694924
# 2000-04-30  1.730237 -3.655785  0.368995  1.538193
# 2000-05-31  1.181425 -3.593500 -0.357252  2.472833

# %%
ax = sns.scatterplot(data=wide_df)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Adding regression plot line
#
# We can use the sns.lmplot command to add two regression lines (corresponding to smokers and nonsmokers).

# %%
# obs: adding the columns - 'total_bill' and 'tip' 
sns.scatterplot(x = tips['total_bill'], y = tips['tip'], hue = tips['time'] );

# %%
sns.lmplot(data = tips, x = 'total_bill', y = 'tip', hue = 'time');
